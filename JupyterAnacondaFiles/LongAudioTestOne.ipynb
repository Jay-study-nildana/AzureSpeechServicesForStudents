# %%
import json
import ntpath
import requests

# %%
def get_voices():
    region = 'centralindia'
    key = '9dabdc080b9844fea9fcffca8f611331'
    url = 'https://{}.customvoice.api.speech.microsoft.com/api/texttospeech/v3.0/longaudiosynthesis/voices'.format(region)
    header = {
        'Ocp-Apim-Subscription-Key': key
    }

    response = requests.get(url, headers=header)
    print(response.text)

get_voices()
# Out:
# {
#   "values": [
#     {
#       "locale": "zh-CN",
#       "voiceName": "zh-CN-XiaoxuanNeural",
#       "description": "{\"Version\":\"20211130133950\"}",
#       "gender": "Female",
#       "createdDateTime": "2021-11-30T16:50:58.120Z",
#       "properties": {
#         "publicAvailable": true,
#         "roles": [
#           {
#             "name": "MaleYoung"
#           },
#           {
#             "name": "Default"
#           }
#         ],
#         "styles": [
#           {
#             "name": "Embarrassed"
#           },
#           {
#             "name": "Calm"
#           },
#           {
#             "name": "Fearful"
#           },
#           {
#             "name": "Cheerful"
#           },
#           {
#             "name": "Disgruntled"
#           },
#           {
#             "name": "Serious"
#           },
#           {
#             "name": "Angry"
#           },
#           {
#             "name": "Sad"
#           },
#           {
#             "name": "Depressed"
#           },
#           {
#             "name": "Default"
#           }
#         ]
#       }
#     },
#     {
#       "locale": "zh-CN",
#       "voiceName": "zh-CN-YunyeNeural",
#       "description": "{\"Version\":\"20211130133950\"}",
#       "gender": "Male",
#       "createdDateTime": "2021-11-30T17:31:55.100Z",
#       "properties": {
#         "publicAvailable": true,
#         "roles": [
#           {
#             "name": "Default"
#           },
#           {
#             "name": "YoungAdultMale"
#           },
#           {
#             "name": "OlderAdultMale"
#           },
#           {
#             "name": "SeniorMale"
#           },
#           {
#             "name": "YoungAdultFemale"
#           },
#           {
#             "name": "OlderAdultFemale"
#           },
#           {
#             "name": "SeniorFemale"
#           },
#           {
#             "name": "Girl"
#           },
#           {
#             "name": "Boy"
#           }
#         ],
#         "styles": [
#           {
#             "name": "Default"
#           },
#           {
#             "name": "Embarrassed"
#           },
#           {
#             "name": "Calm"
#           },
#           {
#             "name": "Fearful"
#           },
#           {
#             "name": "Cheerful"
#           },
#           {
#             "name": "Disgruntled"
#           },
#           {
#             "name": "Serious"
#           },
#           {
#             "name": "Angry"
#           },
#           {
#             "name": "Sad"
#           },
#           {
#             "name": "Depressed"
#           },
#           {
#             "name": "Affectionate"
#           },
#           {
#             "name": "Gentle"
#           },
#           {
#             "name": "Envy"
#           }
#         ]
#       }
#     },
#     {
#       "locale": "de-DE",
#       "voiceName": "de-DE-KatjaNeural",
#       "description": "{\"Version\":\"20211130133950\"}",
#       "gender": "Female",
#       "createdDateTime": "2021-11-30T13:48:12.937Z",
#       "properties": {
#         "publicAvailable": true
#       }
#     },
#     {
#       "locale": "fr-FR",
#       "voiceName": "fr-FR-DeniseNeural",
#       "description": "{\"Version\":\"20211130133950\"}",
#       "gender": "Female",
#       "createdDateTime": "2021-11-30T14:52:36.197Z",
#       "properties": {
#         "publicAvailable": true,
#         "styles": [
#           {
#             "name": "Cheerful"
#           },
#           {
#             "name": "Sad"
#           },
#           {
#             "name": "Default"
#           }
#         ]
#       }
#     },
#     {
#       "locale": "zh-CN",
#       "voiceName": "zh-CN-XiaomoNeural",
#       "description": "{\"Version\":\"20211130133950\"}",
#       "gender": "Female",
#       "createdDateTime": "2021-11-30T15:53:16.600Z",
#       "properties": {
#         "publicAvailable": true,
#         "roles": [
#           {
#             "name": "Default"
#           },
#           {
#             "name": "YoungAdultMale"
#           },
#           {
#             "name": "OlderAdultMale"
#           },
#           {
#             "name": "SeniorMale"
#           },
#           {
#             "name": "YoungAdultFemale"
#           },
#           {
#             "name": "OlderAdultFemale"
#           },
#           {
#             "name": "SeniorFemale"
#           },
#           {
#             "name": "Girl"
#           },
#           {
#             "name": "Boy"
#           }
#         ],
#         "styles": [
#           {
#             "name": "Default"
#           },
#           {
#             "name": "Embarrassed"
#           },
#           {
#             "name": "Calm"
#           },
#           {
#             "name": "Fearful"
#           },
#           {
#             "name": "Cheerful"
#           },
#           {
#             "name": "Disgruntled"
#           },
#           {
#             "name": "Serious"
#           },
#           {
#             "name": "Angry"
#           },
#           {
#             "name": "Sad"
#           },
#           {
#             "name": "Depressed"
#           },
#           {
#             "name": "Affectionate"
#           },
#           {
#             "name": "Gentle"
#           },
#           {
#             "name": "Envy"
#           }
#         ]
#       }
#     },
#     {
#       "locale": "es-MX",
#       "voiceName": "es-MX-DaliaNeural",
#       "description": "{\"Version\":\"20211130133950\"}",
#       "gender": "Female",
#       "createdDateTime": "2021-11-30T14:40:27.380Z",
#       "properties": {
#         "publicAvailable": true
#       }
#     },
#     {
#       "locale": "zh-CN",
#       "voiceName": "zh-CN-YunxiNeural",
#       "description": "{\"Version\":\"20211130133950\"}",
#       "gender": "Male",
#       "createdDateTime": "2021-11-30T17:08:55.927Z",
#       "properties": {
#         "publicAvailable": true,
#         "roles": [
#           {
#             "name": "Default"
#           },
#           {
#             "name": "Narrator"
#           },
#           {
#             "name": "YoungAdultMale"
#           },
#           {
#             "name": "Boy"
#           }
#         ],
#         "styles": [
#           {
#             "name": "Default"
#           },
#           {
#             "name": "Narrative"
#           },
#           {
#             "name": "Embarrassed"
#           },
#           {
#             "name": "Calm"
#           },
#           {
#             "name": "Fearful"
#           },
#           {
#             "name": "Cheerful"
#           },
#           {
#             "name": "Disgruntled"
#           },
#           {
#             "name": "Serious"
#           },
#           {
#             "name": "Angry"
#           },
#           {
#             "name": "Sad"
#           },
#           {
#             "name": "Depressed"
#           },
#           {
#             "name": "Chat"
#           },
#           {
#             "name": "Assistant"
#           },
#           {
#             "name": "VoiceAssistant"
#           }
#         ]
#       }
#     },
#     {
#       "locale": "ko-KR",
#       "voiceName": "ko-KR-SunHiNeural",
#       "description": "{\"Version\":\"20211130133950\"}",
#       "gender": "Female",
#       "createdDateTime": "2021-11-30T15:12:30.197Z",
#       "properties": {
#         "publicAvailable": true
#       }
#     },
#     {
#       "locale": "zh-CN",
#       "voiceName": "zh-CN-XiaohanNeural",
#       "description": "{\"Version\":\"20211130133950\"}",
#       "gender": "Female",
#       "createdDateTime": "2021-11-30T15:42:22.103Z",
#       "properties": {
#         "publicAvailable": true,
#         "roles": [
#           {
#             "name": "MaleYoung"
#           },
#           {
#             "name": "Default"
#           }
#         ],
#         "styles": [
#           {
#             "name": "Embarrassed"
#           },
#           {
#             "name": "Calm"
#           },
#           {
#             "name": "Fearful"
#           },
#           {
#             "name": "Cheerful"
#           },
#           {
#             "name": "Disgruntled"
#           },
#           {
#             "name": "Serious"
#           },
#           {
#             "name": "Angry"
#           },
#           {
#             "name": "Sad"
#           },
#           {
#             "name": "Depressed"
#           },
#           {
#             "name": "Default"
#           }
#         ]
#       }
#     },
#     {
#       "locale": "en-US",
#       "voiceName": "en-US-JennyNeural",
#       "description": "{\"Version\":\"20211216015304\"}",
#       "gender": "Female",
#       "createdDateTime": "2021-12-16T02:01:05.240Z",
#       "properties": {
#         "publicAvailable": true,
#         "styles": [
#           {
#             "name": "chat"
#           },
#           {
#             "name": "customerservice"
#           },
#           {
#             "name": "assistant"
#           },
#           {
#             "name": "newscast"
#           },
#           {
#             "name": "newscast-formal"
#           },
#           {
#             "name": "newscast-casual"
#           },
#           {
#             "name": "Default"
#           }
#         ]
#       }
#     },
#     {
#       "locale": "nb-NO",
#       "voiceName": "nb-NO-IselinNeural",
#       "description": "{\"Version\":\"20211130133950\"}",
#       "gender": "Female",
#       "createdDateTime": "2021-11-30T15:17:25.600Z",
#       "properties": {
#         "publicAvailable": true
#       }
#     },
#     {
#       "locale": "tr-TR",
#       "voiceName": "tr-TR-EmelNeural",
#       "description": "{\"Version\":\"20211130133950\"}",
#       "gender": "Female",
#       "createdDateTime": "2021-11-30T15:27:56.583Z",
#       "properties": {
#         "publicAvailable": true
#       }
#     },
#     {
#       "locale": "en-CA",
#       "voiceName": "en-CA-ClaraNeural",
#       "description": "{\"Version\":\"20211130133950\"}",
#       "gender": "Female",
#       "createdDateTime": "2021-11-30T14:01:00.740Z",
#       "properties": {
#         "publicAvailable": true
#       }
#     },
#     {
#       "locale": "zh-CN",
#       "voiceName": "zh-CN-XiaoyouNeural",
#       "description": "{\"Version\":\"20211130133950\"}",
#       "gender": "Male",
#       "createdDateTime": "2021-11-30T16:55:36.773Z",
#       "properties": {
#         "publicAvailable": true
#       }
#     },
#     {
#       "locale": "zh-CN",
#       "voiceName": "zh-CN-XiaoruiNeural",
#       "description": "{\"Version\":\"20211130133950\"}",
#       "gender": "Female",
#       "createdDateTime": "2021-11-30T16:17:12.143Z",
#       "properties": {
#         "publicAvailable": true,
#         "roles": [
#           {
#             "name": "MaleYoung"
#           },
#           {
#             "name": "Default"
#           }
#         ],
#         "styles": [
#           {
#             "name": "Embarrassed"
#           },
#           {
#             "name": "Calm"
#           },
#           {
#             "name": "Fearful"
#           },
#           {
#             "name": "Cheerful"
#           },
#           {
#             "name": "Disgruntled"
#           },
#           {
#             "name": "Serious"
#           },
#           {
#             "name": "Angry"
#           },
#           {
#             "name": "Sad"
#           },
#           {
#             "name": "Depressed"
#           },
#           {
#             "name": "Default"
#           }
#         ]
#       }
#     },
#     {
#       "locale": "pt-BR",
#       "voiceName": "pt-BR-FranciscaNeural",
#       "description": "{\"Version\":\"20211130133950\"}",
#       "gender": "Female",
#       "createdDateTime": "2021-11-30T15:24:23.727Z",
#       "properties": {
#         "publicAvailable": true,
#         "styles": [
#           {
#             "name": "calm"
#           },
#           {
#             "name": "cheerful"
#           },
#           {
#             "name": "Default"
#           }
#         ]
#       }
#     },
#     {
#       "locale": "en-GB",
#       "voiceName": "en-GB-LibbyNeural",
#       "description": "{\"Version\":\"20211130133950\"}",
#       "gender": "Female",
#       "createdDateTime": "2021-11-30T14:06:09.390Z",
#       "properties": {
#         "publicAvailable": true
#       }
#     },
#     {
#       "locale": "it-IT",
#       "voiceName": "it-IT-ElsaNeural",
#       "description": "{\"Version\":\"20211130133950\"}",
#       "gender": "Female",
#       "createdDateTime": "2021-11-30T14:58:02.670Z",
#       "properties": {
#         "publicAvailable": true
#       }
#     },
#     {
#       "locale": "en-AU",
#       "voiceName": "en-AU-NatashaNeural",
#       "description": "{\"Version\":\"20211130133950\"}",
#       "gender": "Female",
#       "createdDateTime": "2021-11-30T13:47:28.283Z",
#       "properties": {
#         "publicAvailable": true
#       }
#     },
#     {
#       "locale": "es-ES",
#       "voiceName": "es-ES-ElviraNeural",
#       "description": "{\"Version\":\"20211130133950\"}",
#       "gender": "Female",
#       "createdDateTime": "2021-11-30T14:33:51.743Z",
#       "properties": {
#         "publicAvailable": true
#       }
#     },
#     {
#       "locale": "en-US",
#       "voiceName": "en-US-GuyNeural",
#       "description": "{\"Version\":\"20211130133950\"}",
#       "gender": "Male",
#       "createdDateTime": "2021-11-30T14:38:32.267Z",
#       "properties": {
#         "publicAvailable": true,
#         "styles": [
#           {
#             "name": "newscast"
#           },
#           {
#             "name": "Default"
#           }
#         ]
#       }
#     },
#     {
#       "locale": "ja-JP",
#       "voiceName": "ja-JP-KeitaNeural",
#       "description": "{\"Version\":\"20211130133950\"}",
#       "gender": "Male",
#       "createdDateTime": "2021-11-30T15:03:09.610Z",
#       "properties": {
#         "publicAvailable": true
#       }
#     },
#     {
#       "locale": "fr-CA",
#       "voiceName": "fr-CA-SylvieNeural",
#       "description": "{\"Version\":\"20211130133950\"}",
#       "gender": "Female",
#       "createdDateTime": "2021-11-30T14:46:14.523Z",
#       "properties": {
#         "publicAvailable": true
#       }
#     },
#     {
#       "locale": "zh-CN",
#       "voiceName": "zh-CN-YunyangNeural",
#       "description": "{\"Version\":\"20211130133950\"}",
#       "gender": "Male",
#       "createdDateTime": "2021-11-30T17:15:08.020Z",
#       "properties": {
#         "publicAvailable": true
#       }
#     },
#     {
#       "locale": "zh-CN",
#       "voiceName": "zh-CN-XiaoxiaoNeural",
#       "description": "{\"Version\":\"20211130133950\"}",
#       "gender": "Female",
#       "createdDateTime": "2021-11-30T16:30:37.033Z",
#       "properties": {
#         "publicAvailable": true,
#         "styles": [
#           {
#             "name": "lyrical"
#           },
#           {
#             "name": "sentiment"
#           },
#           {
#             "name": "customerservice"
#           },
#           {
#             "name": "newscast"
#           },
#           {
#             "name": "voiceassistant"
#           },
#           {
#             "name": "assistant"
#           },
#           {
#             "name": "chat"
#           },
#           {
#             "name": "gentle"
#           },
#           {
#             "name": "affectionate"
#           },
#           {
#             "name": "disgruntled"
#           },
#           {
#             "name": "fearful"
#           },
#           {
#             "name": "calm"
#           },
#           {
#             "name": "cheerful"
#           },
#           {
#             "name": "angry"
#           },
#           {
#             "name": "serious"
#           },
#           {
#             "name": "sad"
#           },
#           {
#             "name": "Default"
#           }
#         ]
#       }
#     },
#     {
#       "locale": "en-GB",
#       "voiceName": "en-GB-MiaNeural",
#       "description": "{\"Version\":\"20211130133950\"}",
#       "gender": "Female",
#       "createdDateTime": "2021-11-30T14:10:12.510Z",
#       "properties": {
#         "publicAvailable": true
#       }
#     },
#     {
#       "locale": "en-US",
#       "voiceName": "en-US-AriaNeural",
#       "description": "{\"Version\":\"20211130133950\"}",
#       "gender": "Female",
#       "createdDateTime": "2021-11-30T14:14:48.243Z",
#       "properties": {
#         "publicAvailable": true,
#         "styles": [
#           {
#             "name": "cheerful"
#           },
#           {
#             "name": "empathy"
#           },
#           {
#             "name": "empathetic"
#           },
#           {
#             "name": "chat"
#           },
#           {
#             "name": "newscast"
#           },
#           {
#             "name": "newscast-formal"
#           },
#           {
#             "name": "customerservice"
#           },
#           {
#             "name": "newscast-casual"
#           },
#           {
#             "name": "narration-professional"
#           },
#           {
#             "name": "Default"
#           }
#         ]
#       }
#     },
#     {
#       "locale": "ja-JP",
#       "voiceName": "ja-JP-NanamiNeural",
#       "description": "{\"Version\":\"20211130133950\"}",
#       "gender": "Female",
#       "createdDateTime": "2021-11-30T15:10:16.460Z",
#       "properties": {
#         "publicAvailable": true,
#         "styles": [
#           {
#             "name": "General"
#           },
#           {
#             "name": "chat"
#           },
#           {
#             "name": "customerservice"
#           },
#           {
#             "name": "cheerful"
#           },
#           {
#             "name": "Default"
#           }
#         ]
#       }
#     }
#   ]
# }

# %%
def submit_synthesis():
    region = 'centralindia'
    key = '9dabdc080b9844fea9fcffca8f611331'
    input_file_path = 'samplefile.txt'
    locale = 'en-GB'
    url = 'https://{}.customvoice.api.speech.microsoft.com/api/texttospeech/v3.0/longaudiosynthesis'.format(region)
    header = {
        'Ocp-Apim-Subscription-Key': key
    }

    voice_identities = [
        {
            'voicename': 'en-GB-LibbyNeural'
        }
    ]

    payload = {
        'displayname': 'long audio synthesis sample',
        'description': 'sample description',
        'locale': locale,
        'voices': json.dumps(voice_identities),
        'outputformat': 'riff-16khz-16bit-mono-pcm',
        'concatenateresult': True,
    }

    filename = ntpath.basename(input_file_path)
    files = {
        'script': (filename, open(input_file_path, 'rb'), 'text/plain')
    }

    response = requests.post(url, payload, headers=header, files=files)
    print('response.status_code: %d' % response.status_code)
    print(response.headers['Location'])

submit_synthesis()
# Out:
# response.status_code: 202
# https://centralindia.customvoice.api.speech.microsoft.com/api/texttospeech/v3.0/longaudiosynthesis/a946ab8f-2eb3-4ca9-bc77-fc9f32dea0d9

# %%
def get_synthesis():
    url = 'https://centralindia.customvoice.api.speech.microsoft.com/api/texttospeech/v3.0/longaudiosynthesis/a946ab8f-2eb3-4ca9-bc77-fc9f32dea0d9'
    key = '9dabdc080b9844fea9fcffca8f611331'
    header = {
        'Ocp-Apim-Subscription-Key': key
    }
    response = requests.get(url, headers=header)
    print(response.text)

get_synthesis()
# Out:
# {
#   "models": [
#     {
#       "voiceName": "en-GB-LibbyNeural"
#     }
#   ],
#   "properties": {
#     "outputFormat": "riff-16khz-16bit-mono-pcm",
#     "concatenateResult": true,
#     "totalDuration": "PT41.075S",
#     "billableCharacterCount": 549
#   },
#   "id": "a946ab8f-2eb3-4ca9-bc77-fc9f32dea0d9",
#   "lastActionDateTime": "2022-01-23T19:16:28.033Z",
#   "status": "Succeeded",
#   "createdDateTime": "2022-01-23T19:16:04.600Z",
#   "locale": "en-GB",
#   "displayName": "long audio synthesis sample",
#   "description": "sample description"
# }

# %%
def get_files():
    id = 'a946ab8f-2eb3-4ca9-bc77-fc9f32dea0d9'
    region = 'centralindia'
    key = '9dabdc080b9844fea9fcffca8f611331'
    url = 'https://{}.customvoice.api.speech.microsoft.com/api/texttospeech/v3.0/longaudiosynthesis/{}/files'.format(region, id)
    header = {
        'Ocp-Apim-Subscription-Key': key
    }

    response = requests.get(url, headers=header)
    print('response.status_code: %d' % response.status_code)
    print(response.text)

get_files()
# Out:
# response.status_code: 200
# {
#   "values": [
#     {
#       "name": "e1e30bbb-d18b-4592-9689-eb252c139ab3.txt",
#       "kind": "LongAudioSynthesisScript",
#       "properties": {
#         "size": 564
#       },
#       "createdDateTime": "2022-01-23T19:16:04.566Z",
#       "links": {
#         "contentUrl": "https://cvoiceprodinc.blob.core.windows.net/bestor-948e9f4b-98f0-414a-b695-603be7bddabe/VoiceSynthesisData/e1e30bbb-d18b-4592-9689-eb252c139ab3.txt?sv=2019-07-07&sr=b&sig=hgE2zGiM%2Fz6YEy7uOdlyblr4mbRY%2FjZdYMYLk2m%2FInI%3D&st=2022-01-23T19:13:15Z&se=2022-01-24T07:18:15Z&sp=rl"
#       }
#     },
#     {
#       "name": "voicesynthesis_waves.zip",
#       "kind": "LongAudioSynthesisResult",
#       "properties": {
#         "size": 930615
#       },
#       "createdDateTime": "2022-01-23T19:16:28.003Z",
#       "links": {
#         "contentUrl": "https://cvoiceprodinc.blob.core.windows.net/bestor-948e9f4b-98f0-414a-b695-603be7bddabe/VoiceSynthesisData/c6d219fe-c4a0-42b6-bc6d-4251440e598e?sv=2019-07-07&sr=b&sig=rTE70LrhobUEZ5sdE7dBaRbBpWQDG0AlvjlmQi8TCgA%3D&st=2022-01-23T19:13:15Z&se=2022-01-24T07:18:15Z&sp=rl"
#       }
#     }
#   ]
# }
